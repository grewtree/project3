# %%
import pandas as pd

# %%
pd.set_option('display.max_seq_items', None)
# # row 생략 없이 출력
# pd.set_option('display.max_rows', None)
# # col 생략 없이 출력
# pd.set_option('display.max_columns', None)

# %%
df_kospi = pd.read_csv('./data/kospi_p3.csv')
df_kospi.head()
# Out:
#    year  month        Close
# 0  2010      1  1682.157500
# 1  2010      2  1598.956316
# 2  2010      3  1665.504091
# 3  2010      4  1730.286818
# 4  2010      5  1648.300000

# %%
df_unemployment = pd.read_csv('./data/unemployment_p3.csv', encoding='utf-8')
df_unemployment.head()
# Out:
#        시점     계    계.1    계.2    계.3    계.4    계.5    계.6    계.7      계.8  \
# 0      시점     계  서울특별시  부산광역시  대구광역시  인천광역시  광주광역시  대전광역시  울산광역시  세종특별자치시
# 1  2010-1  1218    313     81     75     85     32     34     23        -
# 2  2010-2  1170    305     73     58     88     29     36     22        -
# 3  2010-3  1007    273     64     53     75     29     28     23        -
# 4  2010-4   936    270     62     44     67     31     29     21        -
#
#    ...     여자.8 여자.9 여자.10 여자.11 여자.12 여자.13 여자.14 여자.15 여자.16 여자.17
# 0  ...  세종특별자치시  경기도   강원도  충청북도  충청남도  전라북도  전라남도  경상북도  경상남도   제주도
# 1  ...        -  120    11     9    17     8    18    30    23     4
# 2  ...        -  118    10     7    18     8    13    22    24     4
# 3  ...        -  102     6     4     9     7     7    16    24     3
# 4  ...        -   85     4     5     7     6     5    17    16     4
#
# [5 rows x 55 columns]

# %%
df_unemployment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 55 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시점      150 non-null    object
#  1   계       150 non-null    object
#  2   계.1     150 non-null    object
#  3   계.2     150 non-null    object
#  4   계.3     150 non-null    object
#  5   계.4     150 non-null    object
#  6   계.5     150 non-null    object
#  7   계.6     150 non-null    object
#  8   계.7     150 non-null    object
#  9   계.8     150 non-null    object
#  10  계.9     150 non-null    object
#  11  계.10    150 non-null    object
#  12  계.11    150 non-null    object
#  13  계.12    150 non-null    object
#  14  계.13    150 non-null    object
#  15  계.14    150 non-null    object
#  16  계.15    150 non-null    object
#  17  계.16    150 non-null    object
#  18  계.17    150 non-null    object
#  19  남자      150 non-null    object
#  20  남자.1    150 non-null    object
# ...

# %%
df_sum = df_unemployment.iloc[:, :19]
df_sum.head(13)
# Out:
#          시점     계    계.1    계.2    계.3    계.4    계.5    계.6    계.7      계.8  \
# 0        시점     계  서울특별시  부산광역시  대구광역시  인천광역시  광주광역시  대전광역시  울산광역시  세종특별자치시
# 1   2010.01  1218    313     81     75     85     32     34     23        -
# 2   2010.02  1170    305     73     58     88     29     36     22        -
# 3   2010.03  1007    273     64     53     75     29     28     23        -
# 4   2010.04   936    270     62     44     67     31     29     21        -
# 5   2010.05   798    224     50     43     57     26     22     17        -
# 6   2010.06   878    226     55     46     61     28     26     19        -
# 7   2010.07   936    240     61     51     68     24     31     19        -
# 8   2010.08   836    228     52     38     59     25     25     15        -
# 9   2010.09   864    231     59     46     68     20     18     18        -
# 10   2010.1   838    244     56     41     74     15     22     16        -
# ...

# %%
df_total = pd.DataFrame({'loc':[], 'year':[], 'month':[], 'unemployment':[]})

# %%
df_total
# Out:
# Empty DataFrame
# Columns: [loc, year, month, unemployment]
# Index: []

# %%
import datetime

a = df_sum['시점'].str.split('.')
# a = pd.DataFrame(a)
a
# Out:
# 0            [시점]
# 1      [2010, 01]
# 2      [2010, 02]
# 3      [2010, 03]
# 4      [2010, 04]
#           ...
# 145    [2022, 01]
# 146    [2022, 02]
# 147    [2022, 03]
# 148    [2022, 04]
# 149    [2022, 05]
# Name: 시점, Length: 150, dtype: object

# %%
i=1
lss = []
while i < len(a) : 
    lss.append(a[i][1])
    i += 1
    # df_total['year'].append(a)

df_total.month = lss

# %%
i=1
ls = []
while i < len(a) : 
    ls.append(a[i][0])
    i += 1
    # df_total['year'].append(a)

df_total.year = ls

# %%
df_total
# Out:
#      loc  year month  unemployment
# 0    NaN  2010    01           NaN
# 1    NaN  2010    02           NaN
# 2    NaN  2010    03           NaN
# 3    NaN  2010    04           NaN
# 4    NaN  2010    05           NaN
# ..   ...   ...   ...           ...
# 144  NaN  2022    01           NaN
# 145  NaN  2022    02           NaN
# 146  NaN  2022    03           NaN
# 147  NaN  2022    04           NaN
# 148  NaN  2022    05           NaN
#
# [149 rows x 4 columns]

# %%
df_total
# Out:
# Index(['시점', '계', '계.1', '계.2', '계.3', '계.4', '계.5', '계.6', '계.7', '계.8',
#        '계.9', '계.10', '계.11', '계.12', '계.13', '계.14', '계.15', '계.16', '계.17'],
#       dtype='object')

# %%
df_sum
header = df_sum.iloc[0]
df_sum = df_sum[1:]

df_sum.rename(columns = header, inplace=True)
# Out:
# C:\Users\leech\AppData\Local\Temp\ipykernel_12164\551351051.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sum.rename(columns = header, inplace=True)

# %%
df_sum = df_sum.drop(columns = '계')
df_sum
# Out:
#           시점 서울특별시 부산광역시 대구광역시 인천광역시 광주광역시 대전광역시 울산광역시 세종특별자치시  경기도 강원도 충청북도  \
# 1    2010.01   313    81    75    85    32    34    23       -  295  32   26
# 2    2010.02   305    73    58    88    29    36    22       -  311  27   24
# 3    2010.03   273    64    53    75    29    28    23       -  258  23   15
# 4    2010.04   270    62    44    67    31    29    21       -  224  15   16
# 5    2010.05   224    50    43    57    26    22    17       -  195  14   14
# ..       ...   ...   ...   ...   ...   ...   ...   ...     ...  ...  ..  ...
# 145  2022.01   250    75    49    80    32    33    24       5  246  49   34
# 146  2022.02   230    53    41    57    29    27    23       5  229  33   31
# 147  2022.03   218    45    35    50    28    22    19       5  201  32   24
# 148  2022.04   206    43    40    55    22    18    22       4  219  22   25
# 149  2022.05   186    51    44    64    21    18    21       5  247  20   28
#
#     충청남도 전라북도 전라남도 경상북도 경상남도 제주도
# ...

# %%
df_sum.iloc[:,1]
# Out:
# 1      313
# 2      305
# 3      273
# 4      270
# 5      224
#       ...
# 145    250
# 146    230
# 147    218
# 148    206
# 149    186
# Name: 서울특별시, Length: 149, dtype: object

# %%
pd.concat([df_sum['시점'].iloc[1:,:], df_sum.iloc[:,1]], axis =1)
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# c:\Users\leech\Desktop\dev\project3_git\test.ipynb Cell 15' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/leech/Desktop/dev/project3_git/test.ipynb#ch0000022?line=0'>1</a> pd.concat([df_sum['시점'].iloc[1:,:], df_sum.iloc[:,1]], axis =1)
#
# File c:\Users\leech\anaconda3\envs\project3\lib\site-packages\pandas\core\indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File c:\Users\leech\anaconda3\envs\project3\lib\site-packages\pandas\core\indexing.py:1458, in _iLocIndexer._getitem_tuple(self, tup)
# ...

# %%
df = pd.concat([df_sum['시점'], df_sum.iloc[:,1]], axis =1)
df
# Out:
#           시점 서울특별시
# 1    2010.01   313
# 2    2010.02   305
# 3    2010.03   273
# 4    2010.04   270
# 5    2010.05   224
# ..       ...   ...
# 145  2022.01   250
# 146  2022.02   230
# 147  2022.03   218
# 148  2022.04   206
# 149  2022.05   186
#
# [149 rows x 2 columns]

# %%
a = df['시점'].str.split('.')
a
# Out:
# 1      [2010, 01]
# 2      [2010, 02]
# 3      [2010, 03]
# 4      [2010, 04]
# 5      [2010, 05]
#           ...
# 145    [2022, 01]
# 146    [2022, 02]
# 147    [2022, 03]
# 148    [2022, 04]
# 149    [2022, 05]
# Name: 시점, Length: 149, dtype: object

# %%
a.iloc[0]
# Out:
# ['2010', '01']

# %%
i=0
ls = []
while i < len(a) : 
    ls.append(a.iloc[i][0])
    i += 1

df['year'] = ls

# %%
i=0
lss = []
while i < len(a) : 
    lss.append(a.iloc[i][1])
    i += 1

df['month'] = lss

# %%
df.drop(columns='시점', inplace=True)

# %%
df
# Out:
#     서울특별시  year month
# 1     313  2010    01
# 2     305  2010    02
# 3     273  2010    03
# 4     270  2010    04
# 5     224  2010    05
# ..    ...   ...   ...
# 145   250  2022    01
# 146   230  2022    02
# 147   218  2022    03
# 148   206  2022    04
# 149   186  2022    05
#
# [149 rows x 3 columns]

# %%
df_unemployment = pd.read_csv('./data/unemployment_p3.csv', encoding='utf-8')
df_unemployment
# Out:
#           시점     계    계.1    계.2    계.3    계.4    계.5    계.6    계.7      계.8  \
# 0         시점     계  서울특별시  부산광역시  대구광역시  인천광역시  광주광역시  대전광역시  울산광역시  세종특별자치시
# 1    2010.01  1218    313     81     75     85     32     34     23        -
# 2    2010.02  1170    305     73     58     88     29     36     22        -
# 3    2010.03  1007    273     64     53     75     29     28     23        -
# 4    2010.04   936    270     62     44     67     31     29     21        -
# ..       ...   ...    ...    ...    ...    ...    ...    ...    ...      ...
# 145  2022.01  1143    250     75     49     80     32     33     24        5
# 146  2022.02   954    230     53     41     57     29     27     23        5
# 147  2022.03   873    218     45     35     50     28     22     19        5
# 148  2022.04   864    206     43     40     55     22     18     22        4
# 149  2022.05   889    186     51     44     64     21     18     21        5
#
# ...

# %%
def pre(df_unemployment, ):
    df_sum = df_unemployment.iloc[:, :19]
    header = df_sum.iloc[0]
    df_sum = df_sum[1:]
    df_sum.rename(columns = header, inplace=True)
    df_sum.drop(columns = '계',inplace=True)
    df_sum
# Out:
#           시점 서울특별시 부산광역시 대구광역시 인천광역시 광주광역시 대전광역시 울산광역시 세종특별자치시  경기도 강원도 충청북도  \
# 1    2010.01   313    81    75    85    32    34    23       -  295  32   26
# 2    2010.02   305    73    58    88    29    36    22       -  311  27   24
# 3    2010.03   273    64    53    75    29    28    23       -  258  23   15
# 4    2010.04   270    62    44    67    31    29    21       -  224  15   16
# 5    2010.05   224    50    43    57    26    22    17       -  195  14   14
# ..       ...   ...   ...   ...   ...   ...   ...   ...     ...  ...  ..  ...
# 145  2022.01   250    75    49    80    32    33    24       5  246  49   34
# 146  2022.02   230    53    41    57    29    27    23       5  229  33   31
# 147  2022.03   218    45    35    50    28    22    19       5  201  32   24
# 148  2022.04   206    43    40    55    22    18    22       4  219  22   25
# 149  2022.05   186    51    44    64    21    18    21       5  247  20   28
#
#     충청남도 전라북도 전라남도 경상북도 경상남도 제주도
# ...

# %%
df_loc = pd.concat([df_sum['시점'], df_sum.iloc[:,1]], axis =1)
df_loc
# Out:
#           시점 서울특별시
# 1    2010.01   313
# 2    2010.02   305
# 3    2010.03   273
# 4    2010.04   270
# 5    2010.05   224
# ..       ...   ...
# 145  2022.01   250
# 146  2022.02   230
# 147  2022.03   218
# 148  2022.04   206
# 149  2022.05   186
#
# [149 rows x 2 columns]

# %%
i=0
ls = []
lss = []
while i < len(a) : 
    ls.append(a.iloc[i][0])
    lss.append(a.iloc[i][1])
    i += 1

df_loc['year'] = ls
df_loc['month'] = lss

# %%
df_loc.drop(columns='시점', inplace=True)
df_loc
# Out:
#     서울특별시  year month
# 1     313  2010    01
# 2     305  2010    02
# 3     273  2010    03
# 4     270  2010    04
# 5     224  2010    05
# ..    ...   ...   ...
# 145   250  2022    01
# 146   230  2022    02
# 147   218  2022    03
# 148   206  2022    04
# 149   186  2022    05
#
# [149 rows x 3 columns]

# %%
def pre(df_unemployment, name):
    name = name
    df_sum = df_unemployment.iloc[:, :19]
    header = df_sum.iloc[0]
    df_sum = df_sum[1:]
    df_sum.rename(columns = header, inplace=True)
    df_sum.drop(columns = '계',inplace=True)
    df_loc = pd.concat([df_sum['시점'], df_sum[name]], axis =1)

    i=0
    ls = []
    lss = []
    while i < len(a) : 
        ls.append(a.iloc[i][0])
        lss.append(a.iloc[i][1])
        i += 1

    df_loc['year'] = ls
    df_loc['month'] = lss
    df_loc.drop(columns='시점', inplace=True)

    return df_loc

# %%
name = "부산광역시"
pre(df_unemployment, name)
# Out:
#     부산광역시  year month
# 1      81  2010    01
# 2      73  2010    02
# 3      64  2010    03
# 4      62  2010    04
# 5      50  2010    05
# ..    ...   ...   ...
# 145    75  2022    01
# 146    53  2022    02
# 147    45  2022    03
# 148    43  2022    04
# 149    51  2022    05
#
# [149 rows x 3 columns]

# %%
df_sum.columns
# Out:
# Index(['시점', '서울특별시', '부산광역시', '대구광역시', '인천광역시', '광주광역시', '대전광역시', '울산광역시',
#        '세종특별자치시', '경기도', '강원도', '충청북도', '충청남도', '전라북도', '전라남도', '경상북도', '경상남도',
#        '제주도'],
#       dtype='object')

# %%
df_loc['loc'] = df.columns[0]

# %%
df_loc
# Out:
#     서울특별시  year month    loc
# 1     313  2010    01  서울특별시
# 2     305  2010    02  서울특별시
# 3     273  2010    03  서울특별시
# 4     270  2010    04  서울특별시
# 5     224  2010    05  서울특별시
# ..    ...   ...   ...    ...
# 145   250  2022    01  서울특별시
# 146   230  2022    02  서울특별시
# 147   218  2022    03  서울특별시
# 148   206  2022    04  서울특별시
# 149   186  2022    05  서울특별시
#
# [149 rows x 4 columns]

# %%
str(df_loc.columns[0])
# Out:
# '서울특별시'

# %%
df_loc[['서울특별시','year', 'month']] = df_loc[['서울특별시','year', 'month']].astype(int)

# %%
df_loc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 1 to 149
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   서울특별시   149 non-null    int32
#  1   year    149 non-null    int32
#  2   month   149 non-null    int32
#  3   loc     149 non-null    object
# dtypes: int32(3), object(1)
# memory usage: 3.0+ KB

# %%
df123 = pd.DataFrame({"unemployment":[], "year":[],"month":[], "loc":[]})
df123
# Out:
# Empty DataFrame
# Columns: [unemployment, year, month, loc]
# Index: []

# %%
# df = pd.DataFrame({"unemployment":[], "year":[],"month":[], "loc":[]})

# for i in ls :  
#     name = i
#     df1 = mod1.pre(df_unemployment, name)
#     df = pd.concat([df, df1], axis= 0)

# %%
df_sum.replace('-',0, inplace=True)

# %%
df_sum
# Out:
#           시점 서울특별시 부산광역시 대구광역시 인천광역시 광주광역시 대전광역시 울산광역시 세종특별자치시  경기도 강원도 충청북도  \
# 1    2010.01   313    81    75    85    32    34    23       0  295  32   26
# 2    2010.02   305    73    58    88    29    36    22       0  311  27   24
# 3    2010.03   273    64    53    75    29    28    23       0  258  23   15
# 4    2010.04   270    62    44    67    31    29    21       0  224  15   16
# 5    2010.05   224    50    43    57    26    22    17       0  195  14   14
# ..       ...   ...   ...   ...   ...   ...   ...   ...     ...  ...  ..  ...
# 145  2022.01   250    75    49    80    32    33    24       5  246  49   34
# 146  2022.02   230    53    41    57    29    27    23       5  229  33   31
# 147  2022.03   218    45    35    50    28    22    19       5  201  32   24
# 148  2022.04   206    43    40    55    22    18    22       4  219  22   25
# 149  2022.05   186    51    44    64    21    18    21       5  247  20   28
#
#     충청남도 전라북도 전라남도 경상북도 경상남도 제주도
# ...

# %%
df_sum
# Out:
#           시점 서울특별시 부산광역시 대구광역시 인천광역시 광주광역시 대전광역시 울산광역시 세종특별자치시  경기도 강원도 충청북도  \
# 1    2010.01   313    81    75    85    32    34    23       0  295  32   26
# 2    2010.02   305    73    58    88    29    36    22       0  311  27   24
# 3    2010.03   273    64    53    75    29    28    23       0  258  23   15
# 4    2010.04   270    62    44    67    31    29    21       0  224  15   16
# 5    2010.05   224    50    43    57    26    22    17       0  195  14   14
# ..       ...   ...   ...   ...   ...   ...   ...   ...     ...  ...  ..  ...
# 145  2022.01   250    75    49    80    32    33    24       5  246  49   34
# 146  2022.02   230    53    41    57    29    27    23       5  229  33   31
# 147  2022.03   218    45    35    50    28    22    19       5  201  32   24
# 148  2022.04   206    43    40    55    22    18    22       4  219  22   25
# 149  2022.05   186    51    44    64    21    18    21       5  247  20   28
#
#     충청남도 전라북도 전라남도 경상북도 경상남도 제주도
# ...

# %%
import pandas as pd
import mod1

df_unemployment = pd.read_csv('./data/unemployment_p3.csv', encoding='utf-8')

ls = ['서울특별시', '부산광역시', '대구광역시', '인천광역시', '광주광역시', '대전광역시','울산광역시', '세종특별자치시', '경기도', '강원도', '충청북도', '충청남도', '전라북도', '전라남도', '경상북도', '경상남도','제주도']

# %%
df = pd.DataFrame({"unemployment":[], "year":[],"month":[], "loc":[]})

# %%
for i in ls :  
    name = i
    df1 = mod1.pre(df_unemployment, name)
    df = pd.concat([df, df1], axis= 0)

df.reset_index(drop = True, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\leech\Desktop\dev\project3_git\test.ipynb Cell 46' in <cell line: 1>()
#       <a href='vscode-notebook-cell:/c%3A/Users/leech/Desktop/dev/project3_git/test.ipynb#ch0000058?line=0'>1</a> for i in ls :
#       <a href='vscode-notebook-cell:/c%3A/Users/leech/Desktop/dev/project3_git/test.ipynb#ch0000058?line=1'>2</a>     name = i
# ----> <a href='vscode-notebook-cell:/c%3A/Users/leech/Desktop/dev/project3_git/test.ipynb#ch0000058?line=2'>3</a>     df1 = mod1.pre(df_unemployment, name)
#       <a href='vscode-notebook-cell:/c%3A/Users/leech/Desktop/dev/project3_git/test.ipynb#ch0000058?line=3'>4</a>     df = pd.concat([df, df1], axis= 0)
#       <a href='vscode-notebook-cell:/c%3A/Users/leech/Desktop/dev/project3_git/test.ipynb#ch0000058?line=5'>6</a> df.reset_index(drop = True, inplace=True)
#
# ...

# %%
df_kospi = pd.read_csv('./data/kospi_p3.csv', encoding='utf-8')
df_kospi
# Out:
#      year  month        Close
# 0    2010      1  1682.157500
# 1    2010      2  1598.956316
# 2    2010      3  1665.504091
# 3    2010      4  1730.286818
# 4    2010      5  1648.300000
# ..    ...    ...          ...
# 144  2022      1  2865.552000
# 145  2022      2  2724.015000
# 146  2022      3  2698.716190
# 147  2022      4  2703.242857
# 148  2022      5  2628.338571
#
# [149 rows x 3 columns]

# %%
df_kospi
# Out:
#      year  month        Close
# 0    2010      1  1682.157500
# 1    2010      2  1598.956316
# 2    2010      3  1665.504091
# 3    2010      4  1730.286818
# 4    2010      5  1648.300000
# ..    ...    ...          ...
# 144  2022      1  2865.552000
# 145  2022      2  2724.015000
# 146  2022      3  2698.716190
# 147  2022      4  2703.242857
# 148  2022      5  2628.338571
#
# [149 rows x 3 columns]

# %%
df_kospi.iloc[0]
# Out:
# year     2010.0000
# month       1.0000
# Close    1682.1575
# Name: 0, dtype: float64

# %%
df_rate = pd.read_csv('./data/rate_p3.csv', encoding='utf-8')
df_rate
# Out:
#      year  month        Close
# 0    2010      1  1139.803810
# 1    2010      2  1155.737500
# 2    2010      3  1136.630870
# 3    2010      4  1116.079545
# 4    2010      5  1166.815238
# ..    ...    ...          ...
# 144  2022      1  1195.540000
# 145  2022      2  1197.633000
# 146  2022      3  1220.226522
# 147  2022      4  1236.802381
# 148  2022      5  1265.925909
#
# [149 rows x 3 columns]

# %%
df_interest = pd.read_csv('./data/interest_p3.csv', encoding='utf-8')
df_interest = df_interest.ffill()

df_interest
# Out:
#      year  month  interest
# 0    2010      1      2.00
# 1    2010      2      2.00
# 2    2010      3      2.00
# 3    2010      4      2.00
# 4    2010      5      2.00
# ..    ...    ...       ...
# 144  2022      1      1.25
# 145  2022      2      1.25
# 146  2022      3      1.25
# 147  2022      4      1.50
# 148  2022      5      1.75
#
# [149 rows x 3 columns]

# %%
df_oil = pd.read_csv('./data/oil_p3.csv', encoding='utf-8')
df_oil
# Out:
#      POILDUBUSDM    year  month
# 0      76.713810  2010.0    1.0
# 1      73.553500  2010.0    2.0
# 2      77.367826  2010.0    3.0
# 3      82.984091  2010.0    4.0
# 4      76.620000  2010.0    5.0
# ..           ...     ...    ...
# 144    83.450000  2022.0    1.0
# 145    92.340000  2022.0    2.0
# 146   110.890000  2022.0    3.0
# 147   102.790000  2022.0    4.0
# 148   108.130000  2022.0    5.0
#
# [149 rows x 3 columns]

# %%
df_consume = pd.read_csv('./data/consumerprice_p3.csv', encoding='utf-8')
df_consume
# Out:
#           시점       전국
# 0    2010.01   85.351
# 1    2010.02   85.523
# 2    2010.03   85.696
# 3    2010.04   86.041
# 4    2010.05   86.128
# ..       ...      ...
# 144  2022.01  104.690
# 145  2022.02  105.300
# 146  2022.03  106.060
# 147  2022.04  106.850
# 148  2022.05  107.560
#
# [149 rows x 2 columns]

# %%
df_consume['시점'] = df_consume['시점'].astype(str)
df_consume
# Out:
#           시점       전국
# 0    2010.01   85.351
# 1    2010.02   85.523
# 2    2010.03   85.696
# 3    2010.04   86.041
# 4    2010.05   86.128
# ..       ...      ...
# 144  2022.01  104.690
# 145  2022.02  105.300
# 146  2022.03  106.060
# 147  2022.04  106.850
# 148  2022.05  107.560
#
# [149 rows x 2 columns]

# %%
print(df_consume['시점'].iloc[0].split(".")[0]),
print(df_consume['시점'].iloc[0].split(".")[1])
# Out:
# 2010
# 01

# %%
df_consume['year'] = None
df_consume['month'] = None

i= 0 
while i < len(df_consume):
    df_consume['year'].iloc[i] = df_consume['시점'].iloc[i].split(".")[0]
    df_consume['month'].iloc[i] = df_consume['시점'].iloc[i].split(".")[1]
    i += 1
    
df_consume = df_consume.drop('시점', axis = 1)
# Out:
# C:\Users\leech\AppData\Local\Temp\ipykernel_12164\4110952231.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_consume['year'].iloc[i] = df_consume['시점'].iloc[i].split(".")[0]
# C:\Users\leech\AppData\Local\Temp\ipykernel_12164\4110952231.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_consume['month'].iloc[i] = df_consume['시점'].iloc[i].split(".")[1]

# %%
df_consume
# Out:
#           전국  year month
# 0     85.351  2010    01
# 1     85.523  2010    02
# 2     85.696  2010    03
# 3     86.041  2010    04
# 4     86.128  2010    05
# ..       ...   ...   ...
# 144  104.690  2022    01
# 145  105.300  2022    02
# 146  106.060  2022    03
# 147  106.850  2022    04
# 148  107.560  2022    05
#
# [149 rows x 3 columns]

# %%
df_product = pd.read_csv('./data/productprice_p3.csv', encoding='utf-8')
df_product
# Out:
#           시점  총지수 (2015=100)
# 0    2010.01           96.71
# 1    2010.02           96.88
# 2    2010.03           97.33
# 3    2010.04           98.04
# 4    2010.05           98.87
# ..       ...             ...
# 143  2021.12          113.21
# 144  2022.01          114.40
# 145  2022.02          114.95
# 146  2022.03          116.70
# 147  2022.04          118.02
#
# [148 rows x 2 columns]

# %%
import pandas as pd

def pre(df_unemployment, name):
    name = name
    df_sum = df_unemployment.iloc[:, :19]
    header = df_sum.iloc[0]
    df_sum = df_sum[1:]
    df_sum.rename(columns = header, inplace=True)
    df_sum.drop(columns = '계',inplace=True)
    df_loc = pd.concat([df_sum['시점'], df_sum[name]], axis =1)
    df_loc = df_loc.replace('-', 0)
    a = df_loc['시점'].str.split('-')

    i=0
    ls = []
    lss = []
    while i < len(a) : 
        ls.append(a.iloc[i][0])
        lss.append(a.iloc[i][1])
        i += 1
    df_loc['year'] = ls
    df_loc['month'] = lss
    df_loc.drop(columns='시점', inplace=True)
    df_loc['loc'] = df_loc.columns[0]
    df_loc.rename(columns = {str(df_loc.columns[0]):'unemployment'}, inplace=True)
    df_loc[['unemployment','year', 'month']] = df_loc[['unemployment','year', 'month']].astype(int)
    
    return df_loc

# %%
df_unemployment = pd.read_csv('./data/unemployment_p3.csv', encoding='utf-8')
df_unemployment
